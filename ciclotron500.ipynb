# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
#constantes
q=1#1.6*10**(-19)
m=1#1.672*10**(-27)
Vxo=0.0
Vyo=0.090
Yo=0.0
Xo=-0.1
d=0.05
R=10000.0
Eo=0.15
B=1.0
fi=0.0
dt=0.1
w=q*B/m
print w
# Out:
# 1.0

# %%
#primera posicion AX
#segunda posicion AY

def aceleracion(x,y,vx,vy,t):
    
    ax=-(q/m)*x*B*sqrt((vx**2+vy**2)/(x**2+y**2))
    ay=-(q/m)*y*B*sqrt((vx**2+vy**2)/(x**2+y**2))

    if(-d/2<=y and y<=d/2 and x>0):
       ay=ay+(q/m)*Eo*cos(w*t+fi)
    A=[ax,ay]
    return A

# %%
time=linspace(0,10,1000)
EF=zeros(len(time),dtype="float")

for i in range(len(time)):
    
    EF[i]=Eo*cos(w*time[i])
    
print len(EF),len(time)
# Out:
# 1000 1000

# %%
plot(time,EF)
figsize(5,10)

# %%
i=0
ac=[]
E=[]
x=[]
vx=[]
y=[]
vy=[]
t=[]
r=[]
V=[]
E.append(Eo)
x.append(Xo)
y.append(Yo)
vx.append(Vxo)
vy.append(Vyo)
r.append((x[0]**2+y[0]**2)**0.5)
V.append((vx[0]**2+vy[0]**2)**0.5)
t.append(0)
for i in range(1000):
#while(sqrt(x[-1]**2+y[-1]**2) < R) :
        
        t=append(t,i*(dt+1))
        
        #paso 1------------------------------
        E.append(Eo*cos(w*t[i]))
        t1=t[i]
        x1=x[i]
        y1=y[i]
        vx1=vx[i]
        vy1=vy[i]
        ax1,ay1=aceleracion(x1,y1,vx1,vy1,t1)
        
        kx1=vx1*dt
        lx1=ax1*dt
        ky1=vy1*dt
        ly1=ay1*dt
        
        #paso2-------------------------------
        
        t2=t[i]+0.5*dt
        x2=x[i]+0.5*kx1
        y2=y[i]+0.5*ky1
        vx2=vx[i]+0.5*lx1
        vy2=vy[i]+0.5*ly1
        ax2,ay2=aceleracion(x2,y2,vx2,vy2,t2)
        
        kx2=vx2*dt
        lx2=ax2*dt
        ky2=vy2*dt
        ly2=ay2*dt
        
        #paso3-------------------------------
        
        t3=t[i]+0.5*dt
        x3=x[i]+0.5*kx2
        y3=y[i]+0.5*ky2
        vx3=vx[i]+0.5*lx2
        vy3=vy[i]+0.5*ly2
        ax3,ay3=aceleracion(x3,y3,vx3,vy3,t3)
        
        kx3=vx3*dt
        lx3=ax3*dt
        ky3=vy3*dt
        ly3=ay3*dt
        
        #paso4-------------------------------
        
        t4=t[i]+dt
        x4=x[i]+kx3
        y4=y[i]+ky3
        vx4=vx[i]+lx3
        vy4=vy[i]+ly3
        ax4,ay4=aceleracion(x4,y4,vx4,vy4,t4)
        
        kx4=vx4*dt
        lx4=ax4*dt
        ky4=vy4*dt
        ly4=ay4*dt
        
        Kx=(kx4+2*kx3+2*kx2+kx1)/6
        Ky=(ky4+2*ky3+2*ky2+ky1)/6
        Lx=(lx4+2*lx3+2*lx2+lx1)/6
        Ly=(ly4+2*ly3+2*ly2+ly1)/6
        
        x=append(x,x1+Kx)
        y=append(y,y1+Ky)
        vx=append(vx,vx1+Lx)
        vy=append(vy,vy1+Ly)
        r.append((x[-1]**2+y[-1]**2)**0.5)
        V.append((vx[-1]**2+vy[-1]**2)**0.5)
        
        #i=i+1

# %%
scatter(x,y,c="b",label="trayectorias",s=10)
#plot(x,y,c="k")
#plot(x,y)

dmas=zeros(100)
dmen=zeros(100)
l=zeros(100)
for i in range(100):
    dmas[i]=d/2
    dmen[i]=-d/2
    l[i]=-0.8+i*0.016

plot(l,dmas,"r",linewidth=3)
plot(l,dmen,"r",linewidth=3)
figsize(5,5)
xlabel("$x$",size=15)
ylabel("$y$",size=15,rotation="horizontal")
title("$ciclotron $",size=15)
legend()
xlim(min(x)-0.1,max(x)+0.1)
ylim(min(y)-0.1,max(y)+0.1)
savefig("ciclo_500.png")

# %%
plot(x,y,c="b",label="trayectorias")
#plot(x,y,c="k")
#plot(x,y)

dmas=zeros(100)
dmen=zeros(100)
l=zeros(100)
for i in range(100):
    dmas[i]=d/2
    dmen[i]=-d/2
    l[i]=-0.8+i*0.016

plot(l,dmas,"r",linewidth=3)
plot(l,dmen,"r",linewidth=3)
figsize(5,5)
xlabel("$x$",size=15)
ylabel("$y$",size=15,rotation="horizontal")
title("$ciclotron $",size=15)
legend()
xlim(min(x)-0.1,max(x)+0.1)
ylim(min(y)-0.1,max(y)+0.1)
savefig("ciclo_linea_500.png")

# %%
plot(t,r)
cinetica=zeros(len(V))
for i in range(len(V)):
    cinetica[i]=(m/2.0)*V[i]**2

# %%
plot(t,cinetica)

# %%
from scipy.optimize import curve_fit
def fun(a,b,c,x):
    return a*x**2+b*x+c

valores,otros=curve_fit(fun,t,cinetica)

# %%
print valores
curve=zeros(len(t))
for i in range(len(t)):
    curve[i]=fun(valores[0],valores[1],valores[2],t[i])
# Out:
# [  9.99970700e+02  -4.94146440e+00   4.94136320e-03]

# %%
plot(t,cinetica,label="medicion")
plot(t,curve,label="aproximacion")
#ylim(0,max(cinetica))
legend(loc=2)
scatter(1000,curve[-1])
